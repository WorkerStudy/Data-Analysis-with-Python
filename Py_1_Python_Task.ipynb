# %% [markdown]
# <a href="https://colab.research.google.com/github/WorkerStudy/Data-Analysis-with-Python/blob/main/Py_1_Python_Task.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Задача 0
#
#  Написать, но только с использованием языка разметки markdown в ноутбуке

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Задача 1
#
# Напишите программу, которая выводит на экран текст **«I like programming!»**. Кавычки при выводе не использовать.

# %% [markdown]
# **Sample Input:**

# %% [markdown]
# **Sample Output:**
#
# I like programming!

# %%
print("I like programming!")

# %% [markdown]
# ## Задача 2
#
# Напишите программу, которая выводит на экран текст **«I like programming!»**, необходимо чтобы в каждой отдельной строке было по одному слову. Тройные кавычки при выводе не использовать.

# %% [markdown]
# **Sample Input:**

# %% [markdown]
# **Sample Output:**
#
# I
#
# like
#
# programming!

# %% [markdown]
# ## Задача 3
# Напишите программу, которая выводит на экран текст **«I-like-programming!»** (без кавычек). Кавычки при выводе не использовать.
#
# Необходимо задействовать в качестве параметра **sep** для использования разделителя в виде тире между тремя аргументами (строками), а также **end** для того, чтобы в конце предложения поставить восклицательный знак.

# %% [markdown]
# **Sample Input:**

# %% [markdown]
# **Sample Output:**
#
# I-like-programming!

# %% [markdown]
# ## Задача 4
#
# Напишите программу, которая выводит «Ауууу!» два раза (на отдельных строках; строки должны быть именно такие, символ в символ!).
#
# Важно: поместите эту строку в переменную и выводите уже эту переменную.

# %% [markdown]
# ## Задача 5
#
# Напишите программу, похожую на предыдущую, которая ещё и уточняет, кто какое «Ау» издаёт. Она должна вывести следующее:
#
# Человек: Ауууу!
# Эхо: Ауууу!
#
# Совет: вспомните, как с помощью команды print вывести на одной строке несколько слов, разделённых пробелами. Обязательно сделайте так, чтобы можно было изменить крик человека и ответ эха (они всегда одинаковые), внеся всего одно изменение в программу.
#
# Примечания
# В этой задаче не требуется использовать input()
